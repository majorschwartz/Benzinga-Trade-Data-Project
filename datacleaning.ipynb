# %%
import pandas as pd

# %%
trade_data = pd.read_csv("all_insider_trade_data.csv")
#.iloc[:, 1:]

# %%
trade_data.head()
# Out:
#   company_ticker                company_name  has_trades
# 0           esmt           EngageSmart, Inc.        True  \
# 1           crwd  CrowdStrike Holdings, Inc.        True
# 2           cacc      CREDIT ACCEPTANCE CORP        True
# 3            aur     Aurora Innovation, Inc.        True
# 4           dkng             DraftKings Inc.        True
#
#                                     insider_names    insider_titles_unique
# 0                               Robert P. Bennett  CHIEF EXECUTIVE OFFICER  \
# 1                                    George Kurtz        PRESIDENT AND CEO
# 2  Donald A Foss Irrevocable Trust Dated August                        NaN
# 3                               Sterling Anderson                 DIRECTOR
# 4                                   Stanton Dodge      CHIEF LEGAL OFFICER
#
#                                             insiders
# 0  [{'cik': '0001881869', 'is_director': False, '...  \
# 1  [{'cik': '0001778564', 'is_director': False, '...
# ...

# %%
trade_data.company_ticker.value_counts()
# Out:
# company_ticker
# none      1310
# crm        774
# rcg        742
# tpl        680
# zi         604
#           ...
# snes         1
# cfac         1
# unit         1
# dnow         1
# [cece]       1
# Name: count, Length: 6223, dtype: int64

# %%
trade_data
